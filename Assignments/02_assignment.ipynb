# %%
import pyogrio as ogr
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
import geopandas as gpd
from lonboard import Map, PolygonLayer
from lonboard.colormap import apply_categorical_cmap

# %%
# the bare minimum
import matplotlib.pyplot as plt
import geopandas as gpd

# more advanced
import pyogrio as ogr
from sklearn.cluster import KMeans
from lonboard import Map, PolygonLayer
from lonboard.colormap import apply_categorical_cmap, apply_continuous_cmap
from palettable.colorbrewer.sequential import PuRd_9
from matplotlib.colors import LogNorm

import pydeck as pdk

# %%
# pluto = gpd.read_file("C:\Users\daiyu\Documents\GitHub\cdp-mapping-systems\Data\nyc_mappluto_24v1_1_shp\MapPLUTO.shp.xml")

# %%
pluto_ogrio = ogr.read_dataframe(r"C:\Users\daiyu\Documents\GitHub\cdp-mapping-systems\Data\nyc_mappluto_24v1_1_shp\MapPLUTO.shp")

# %%
# Path to your GeoJSON file
geojson_file_path = r"C:\Users\daiyu\Documents\GitHub\cdp-mapping-systems\Data\weekend.geojson"
# Load GeoJSON file into a GeoDataFrame
gdf = gpd.read_file(geojson_file_path)
# Display the first few rows of the GeoDataFrame
gdf.head()
# Out:
#                      geometry
# 0  POINT (-74.04452 40.68926)
# 1  POINT (-74.04049 40.69894)
# 2  POINT (-74.01736 40.70315)
# 3  POINT (-74.00324 40.72365)
# 4  POINT (-73.99818 40.72351)

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
# Path to your GeoJSON file
geojson_file_path = r"C:\Users\daiyu\Documents\GitHub\cdp-mapping-systems\Data\tourist_attractions_cleaned_f.geojson"
# Load GeoJSON file into a GeoDataFrame
gdf = gpd.read_file(geojson_file_path)
# Display the first few rows of the GeoDataFrame
gdf.head()
# Out:
#                             name   latitude  longitude  num_reviews  \
# 0                Tenement Museum  40.718818 -73.990088         4708
# 1             The Mercury Lounge  40.722168 -73.986746         1202
# 2        Anthology Film Archives  40.724694 -73.990166          267
# 3                   Essex Market  40.718000 -73.988190         6080
# 4  The Angel Orensanz Foundation  40.721165 -73.985720          307
#
#                      geometry
# 0  POINT (-73.99009 40.71882)
# 1  POINT (-73.98675 40.72217)
# 2  POINT (-73.99017 40.72469)
# 3  POINT (-73.98819 40.71800)
# 4  POINT (-73.98572 40.72117)

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
# Paths to the GeoJSON files
geojson_file_path1 = r"C:\Users\daiyu\Documents\GitHub\cdp-mapping-systems\Data\weekend.geojson"
geojson_file_path2 = r"C:\Users\daiyu\Documents\GitHub\cdp-mapping-systems\Data\tourist_attractions_cleaned_f.geojson"

# Load GeoJSON files into GeoDataFrames
gdf1 = gpd.read_file(geojson_file_path1)
gdf2 = gpd.read_file(geojson_file_path2)

# Plot the GeoDataFrames with different colors
fig, ax = plt.subplots()
gdf1.plot(ax=ax, color='red', edgecolor='black', alpha=1, label='File 1')
gdf2.plot(ax=ax, color='blue', edgecolor='black', alpha=0.1, label='File 2')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
# Paths to the Shapefile and GeoJSON files
shapefile_path = r"C:\Users\daiyu\Documents\GitHub\cdp-mapping-systems\Data\nyc_mappluto_24v1_1_shp"
geojson_file_path1 = r"C:\Users\daiyu\Documents\GitHub\cdp-mapping-systems\Data\weekend.geojson"
geojson_file_path2 = r"C:\Users\daiyu\Documents\GitHub\cdp-mapping-systems\Data\tourist_attractions_cleaned_f.geojson"

# Load the Shapefile and GeoJSON files into GeoDataFrames
shapefile_gdf = gpd.read_file(shapefile_path)
gdf1 = gpd.read_file(geojson_file_path1)
gdf2 = gpd.read_file(geojson_file_path2)

# %%
# Plot the Shapefile with the GeoJSON files
fig, ax = plt.subplots()
shapefile_gdf.plot(ax=ax, color='lightgrey', edgecolor='black', alpha=0.5)
gdf1.plot(ax=ax, color='red', edgecolor='black', alpha=0.8, label='File 1')
gdf2.plot(ax=ax, color='blue', edgecolor='black', alpha=0.1, label='File 2')

# Add legend
plt.legend()

# Show plot
plt.show()
